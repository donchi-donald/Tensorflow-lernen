# %% [markdown]
# <a href="https://colab.research.google.com/github/donchi-donald/Tensorflow-lernen/blob/master/06_FashionMNist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import tensorflow.keras as keras

# %%
fashion_mnist = keras.datasets.fashion_mnist

(train_x, train_y), (test_x, test_y) = fashion_mnist.load_data()
train_x = train_x / 255.
test_x = test_x / 255.
# Out:
# ...
# 4431872/4422102 [==============================] - 0s 0us/step

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
model = keras.Sequential([
    keras.layers.Reshape((28,28,1)),
    keras.layers.Conv2D(32,3, activation='relu'),
    keras.layers.Flatten(),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10) #denn wir 10 Klasse haben
])

# %%
model.compile(
    optimizer='adam',
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)

# %%
model.fit(train_x, train_y, epochs=10)
# Out:
# Epoch 1/10
# 1507/1875 [=======================>......] - ETA: 23s - loss: 0.4225 - accuracy: 0.8492

# %%
test_loss, test_acc = model.evaluate(test_x, test_y, verbose=2)
# Out:
# 313/313 - 1s - loss: 0.3346 - accuracy: 0.8776 - 607ms/epoch - 2ms/step

# %%
#Plot
for i in range(100):
    prediction = model(test_x[i:i+1])
    plt.imshow(test_x[i], cmap='gray')
    plt.show()
    print("Prediction", class_names[np.argmax(prediction.numpy())])
# Out:
# Prediction Ankle boot
# Prediction Pullover
# Prediction Trouser
# Prediction Trouser
# Prediction Shirt
# Prediction Trouser
# Prediction Coat
# Prediction Shirt
# Prediction Sandal
# Prediction Sneaker
# Prediction Coat
# Prediction Sandal
# Prediction Sneaker
# Prediction Dress
# Prediction Coat
# Prediction Trouser
# Prediction Pullover
# Prediction Pullover
# Prediction Bag
# Prediction T-shirt/top
# Prediction Pullover
# Prediction Sandal
# Prediction Sneaker
# Prediction Sandal
# Prediction Trouser
# Prediction Pullover
# Prediction Shirt
# Prediction T-shirt/top
# Prediction Ankle boot
# Prediction Dress
# Prediction Bag
# Prediction Bag
# Prediction Dress
# Prediction Dress
# Prediction Bag
# Prediction T-shirt/top
# Prediction Sneaker
# Prediction Sandal
# Prediction Sneaker
# Prediction Ankle boot
# Prediction T-shirt/top
# Prediction Trouser
# Prediction Shirt
# Prediction Sneaker
# Prediction Shirt
# Prediction Sneaker
# Prediction Pullover
# Prediction Trouser
# ...
